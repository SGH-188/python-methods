# %%
#清除第一行

import csv
import pandas as pd
import numpy as np
import os,sys
import re

if __name__ == '__main__':
    for i in range(6, 12):
        
        
        filenames_in = 'C:/Users/1/force/force-3-F/0'+ str(i) + '-5s-F'
        filenames_out = 'C:/Users/1/force/force-4-O/0' + str(i) + '-5s-O'

        pathDir = os.listdir(filenames_in)
        print(pathDir)
        for allDir in pathDir:
            child = re.findall(r"(.+?).csv", allDir)
            if len(child) > 0:
                newfile = ''
                needdate = child
            domain1 = os.path.abspath(filenames_in)
            info = os.path.join(domain1, allDir)
            domain2 = os.path.abspath(filenames_out)
            outfo = os.path.join(domain2, allDir)
        
            n = len(open(info,"r").readlines())
            print(n)
        
            with open(info, 'r') as f:
                with open(outfo,'w') as f1:
                    next(f)
                    for line in f:
                        f1.write(line)
# Out:
# ['06_01-5s-F.csv', '06_02-5s-F.csv', '06_03-5s-F.csv', '06_04-5s-F.csv', '06_05-5s-F.csv', '06_06-5s-F.csv', '06_07-5s-F.csv', '06_08-5s-F.csv', '06_09-5s-F.csv', '06_10-5s-F.csv', '06_11-5s-F.csv', '06_12-5s-F.csv', '06_13-5s-F.csv', '06_14-5s-F.csv', '06_15-5s-F.csv', '06_16-5s-F.csv', '06_17-5s-F.csv', '06_18-5s-F.csv', '06_19-5s-F.csv', '06_20-5s-F.csv', '06_21-5s-F.csv', '06_22-5s-F.csv', '06_23-5s-F.csv', '06_24-5s-F.csv', '06_25-5s-F.csv', '06_26-5s-F.csv', '06_27-5s-F.csv', '06_28-5s-F.csv', '06_29-5s-F.csv', '06_30-5s-F.csv', '06_31-5s-F.csv', '06_32-5s-F.csv', '06_33-5s-F.csv', '06_34-5s-F.csv', '06_35-5s-F.csv', '06_36-5s-F.csv', '06_37-5s-F.csv', '06_38-5s-F.csv', '06_39-5s-F.csv', '06_40-5s-F.csv', '06_41-5s-F.csv', '06_42-5s-F.csv', '06_43-5s-F.csv', '06_44-5s-F.csv', '06_45-5s-F.csv', '06_46-5s-F.csv', '06_47-5s-F.csv']
# 100001
# 100001
# 100001
# 100001
# 100002
# 100002
# 100001
# 100000
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100000
# 100002
# 100002
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100002
# 100002
# 100002
# 100002
# 100001
# ['07_01-5s-F.csv', '07_02-5s-F.csv', '07_03-5s-F.csv', '07_04-5s-F.csv', '07_05-5s-F.csv', '07_06-5s-F.csv', '07_07-5s-F.csv', '07_08-5s-F.csv', '07_09-5s-F.csv', '07_10-5s-F.csv', '07_11-5s-F.csv', '07_12-5s-F.csv', '07_13-5s-F.csv', '07_14-5s-F.csv', '07_15-5s-F.csv', '07_16-5s-F.csv', '07_17-5s-F.csv', '07_18-5s-F.csv', '07_19-5s-F.csv', '07_20-5s-F.csv', '07_21-5s-F.csv', '07_22-5s-F.csv', '07_23-5s-F.csv', '07_24-5s-F.csv', '07_25-5s-F.csv', '07_26-5s-F.csv', '07_27-5s-F.csv', '07_28-5s-F.csv', '07_29-5s-F.csv', '07_30-5s-F.csv', '07_31-5s-F.csv', '07_32-5s-F.csv', '07_33-5s-F.csv', '07_34-5s-F.csv', '07_35-5s-F.csv', '07_36-5s-F.csv', '07_37-5s-F.csv', '07_38-5s-F.csv', '07_39-5s-F.csv']
# 100001
# 100002
# 100001
# 100001
# 100000
# 100002
# 100002
# 100001
# 100000
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100002
# 100002
# 100002
# 100000
# 100000
# 100002
# 100002
# 100001
# 100002
# 100002
# 100001
# 100000
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# ['08_01-5s-F.csv', '08_02-5s-F.csv', '08_03-5s-F.csv', '08_04-5s-F.csv', '08_05-5s-F.csv', '08_06-5s-F.csv', '08_07-5s-F.csv', '08_08-5s-F.csv', '08_09-5s-F.csv', '08_10-5s-F.csv', '08_11-5s-F.csv', '08_12-5s-F.csv', '08_13-5s-F.csv', '08_14-5s-F.csv', '08_15-5s-F.csv', '08_16-5s-F.csv', '08_17-5s-F.csv', '08_18-5s-F.csv', '08_19-5s-F.csv', '08_20-5s-F.csv', '08_21-5s-F.csv', '08_22-5s-F.csv', '08_23-5s-F.csv', '08_24-5s-F.csv', '08_25-5s-F.csv', '08_26-5s-F.csv', '08_27-5s-F.csv', '08_28-5s-F.csv', '08_29-5s-F.csv', '08_30-5s-F.csv', '08_31-5s-F.csv', '08_32-5s-F.csv', '08_33-5s-F.csv', '08_34-5s-F.csv', '08_35-5s-F.csv', '08_36-5s-F.csv', '08_37-5s-F.csv', '08_38-5s-F.csv', '08_39-5s-F.csv', '08_40-5s-F.csv', '08_41-5s-F.csv', '08_42-5s-F.csv', '08_43-5s-F.csv', '08_44-5s-F.csv', '08_45-5s-F.csv', '08_46-5s-F.csv', '08_47-5s-F.csv', '08_48-5s-F.csv', '08_49-5s-F.csv', '08_50-5s-F.csv', '08_51-5s-F.csv', '08_52-5s-F.csv', '08_53-5s-F.csv', '08_54-5s-F.csv', '08_55-5s-F.csv', '08_56-5s-F.csv', '08_57-5s-F.csv']
# 100001
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100002
# 100002
# 100001
# 100001
# 100002
# 100000
# 100000
# 100002
# 100002
# 100000
# 100002
# 100002
# 100000
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100000
# 100000
# 100001
# 100002
# 100002
# 100001
# ['09_01-5s-F.csv', '09_02-5s-F.csv', '09_03-5s-F.csv', '09_04-5s-F.csv', '09_05-5s-F.csv', '09_06-5s-F.csv', '09_07-5s-F.csv', '09_08-5s-F.csv', '09_09-5s-F.csv', '09_10-5s-F.csv', '09_11-5s-F.csv', '09_12-5s-F.csv', '09_13-5s-F.csv', '09_14-5s-F.csv', '09_15-5s-F.csv', '09_16-5s-F.csv', '09_17-5s-F.csv', '09_18-5s-F.csv', '09_19-5s-F.csv', '09_20-5s-F.csv', '09_21-5s-F.csv', '09_22-5s-F.csv', '09_23-5s-F.csv', '09_24-5s-F.csv', '09_25-5s-F.csv', '09_26-5s-F.csv', '09_27-5s-F.csv', '09_28-5s-F.csv', '09_29-5s-F.csv', '09_30-5s-F.csv', '09_31-5s-F.csv', '09_32-5s-F.csv', '09_33-5s-F.csv', '09_34-5s-F.csv', '09_35-5s-F.csv', '09_36-5s-F.csv', '09_37-5s-F.csv', '09_38-5s-F.csv', '09_39-5s-F.csv', '09_40-5s-F.csv', '09_41-5s-F.csv']
# 100001
# 100001
# 100001
# 100001
# 100002
# 100002
# 100002
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100002
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8e224baa7c4c> in <module>
#      14         filenames_out = 'C:/Users/1/force/force-4-O/0' + str(i) + '-5s-O'
#      15
# ---> 16         pathDir = os.listdir(filenames_in)
#      17         print(pathDir)
#      18         for allDir in pathDir:
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: 'C:/Users/1/force/force-3-F/010-5s-F'

# %%
import csv
import pandas as pd
import numpy as np
import os,sys
import re

if __name__ == '__main__':
    for i in range(10, 12):
        
        
        filenames_in = 'C:/Users/1/force/force-3-F/'+ str(i) + '-5s-F'
        filenames_out = 'C:/Users/1/force/force-4-O/' + str(i) + '-5s-O'

        pathDir = os.listdir(filenames_in)
        print(pathDir)
        for allDir in pathDir:
            child = re.findall(r"(.+?).csv", allDir)
            if len(child) > 0:
                newfile = ''
                needdate = child
            domain1 = os.path.abspath(filenames_in)
            info = os.path.join(domain1, allDir)
            domain2 = os.path.abspath(filenames_out)
            outfo = os.path.join(domain2, allDir)
        
            n = len(open(info,"r").readlines())
            print(n)
        
            with open(info, 'r') as f:
                with open(outfo,'w') as f1:
                    next(f)
                    for line in f:
                        f1.write(line)
# Out:
# ['10_01-5s-F.csv', '10_02-5s-F.csv', '10_03-5s-F.csv', '10_04-5s-F.csv', '10_05-5s-F.csv', '10_06-5s-F.csv', '10_07-5s-F.csv', '10_08-5s-F.csv', '10_09-5s-F.csv', '10_10-5s-F.csv', '10_11-5s-F.csv', '10_12-5s-F.csv', '10_13-5s-F.csv', '10_14-5s-F.csv', '10_15-5s-F.csv', '10_16-5s-F.csv', '10_17-5s-F.csv', '10_18-5s-F.csv', '10_19-5s-F.csv', '10_20-5s-F.csv', '10_21-5s-F.csv', '10_22-5s-F.csv', '10_23-5s-F.csv', '10_24-5s-F.csv', '10_25-5s-F.csv', '10_26-5s-F.csv', '10_27-5s-F.csv', '10_28-5s-F.csv', '10_29-5s-F.csv', '10_30-5s-F.csv', '10_31-5s-F.csv', '10_32-5s-F.csv', '10_33-5s-F.csv', '10_34-5s-F.csv', '10_35-5s-F.csv', '10_36-5s-F.csv', '10_37-5s-F.csv', '10_38-5s-F.csv']
# 100001
# 100002
# 100002
# 100000
# 100002
# 100002
# 100000
# 100002
# 100001
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100002
# 100002
# 100000
# 100002
# 100000
# 100001
# 100001
# 100002
# 100002
# 100001
# 100000
# 100001
# 100002
# 100000
# 100001
# 100000
# 100001
# 100002
# 100001
# 100002
# 60001
# ['11_01-5s-F.csv', '11_02-5s-F.csv', '11_03-5s-F.csv', '11_04-5s-F.csv', '11_05-5s-F.csv', '11_06-5s-F.csv', '11_07-5s-F.csv', '11_08-5s-F.csv', '11_09-5s-F.csv', '11_10-5s-F.csv', '11_11-5s-F.csv', '11_12-5s-F.csv', '11_13-5s-F.csv', '11_14-5s-F.csv', '11_15-5s-F.csv', '11_16-5s-F.csv', '11_17-5s-F.csv', '11_18-5s-F.csv', '11_19-5s-F.csv', '11_20-5s-F.csv', '11_21-5s-F.csv', '11_22-5s-F.csv', '11_23-5s-F.csv', '11_24-5s-F.csv', '11_25-5s-F.csv', '11_26-5s-F.csv', '11_27-5s-F.csv', '11_28-5s-F.csv', '11_29-5s-F.csv', '11_30-5s-F.csv', '11_31-5s-F.csv', '11_32-5s-F.csv', '11_33-5s-F.csv', '11_34-5s-F.csv', '11_35-5s-F.csv', '11_36-5s-F.csv', '11_37-5s-F.csv', '11_38-5s-F.csv', '11_39-5s-F.csv', '11_40-5s-F.csv', '11_41-5s-F.csv', '11_42-5s-F.csv', '11_43-5s-F.csv', '11_44-5s-F.csv', '11_45-5s-F.csv', '11_46-5s-F.csv', '11_47-5s-F.csv', '11_48-5s-F.csv', '11_49-5s-F.csv', '11_50-5s-F.csv', '11_51-5s-F.csv', '11_52-5s-F.csv', '11_53-5s-F.csv', '11_54-5s-F.csv', '11_55-5s-F.csv', '11_56-5s-F.csv', '11_57-5s-F.csv', '11_58-5s-F.csv', '11_59-5s-F.csv', '11_60-5s-F.csv', '11_61-5s-F.csv', '11_62-5s-F.csv', '11_63-5s-F.csv', '11_64-5s-F.csv', '11_65-5s-F.csv', '11_66-5s-F.csv', '11_67-5s-F.csv']
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100002
# 100001
# 100002
# 100001
# 100001
# 100002
# 100002
# 100001
# 100001
# 100002
# 100001
# 100002
# 100001
# 100000
# 100001
# 100001
# 100001
# 100002
# 100002
# 100002
# 100002
# 100002
# 100002
# 100002
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100002
# 100002
# 100001
# 100001
# 100002
# 100002
# 100002
# 100001
# 100002
# 100002
# 100002
# 100002
# 100002
# 100001
# 100002
# 100001
# 100001
# 100002
# 100002
# 100001
# 100002
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100001
# 100002
# 100002
# 100002

# %%
import csv
import pandas as pd
import numpy as np
import os,sys
import re

if __name__ == '__main__':
    for i in range(12, 13):
        
        
        filenames_in = 'C:/Users/1/force/force-3-F/'+ str(i) + '-5s-F'
        filenames_out = 'C:/Users/1/force/force-4-O/' + str(i) + '-5s-O'

        pathDir = os.listdir(filenames_in)
        print(pathDir)
        for allDir in pathDir:
            child = re.findall(r"(.+?).csv", allDir)
            if len(child) > 0:
                newfile = ''
                needdate = child
            domain1 = os.path.abspath(filenames_in)
            info = os.path.join(domain1, allDir)
            domain2 = os.path.abspath(filenames_out)
            outfo = os.path.join(domain2, allDir)
        
            n = len(open(info,"r").readlines())
            print(n)
        
            with open(info, 'r') as f:
                with open(outfo,'w') as f1:
                    next(f)
                    for line in f:
                        f1.write(line)
# Out:
# ['12_01-5s-F.csv', '12_02-5s-F.csv', '12_03-5s-F.csv', '12_04-5s-F.csv', '12_05-5s-F.csv', '12_06-5s-F.csv', '12_07-5s-F.csv', '12_08-5s-F.csv', '12_09-5s-F.csv', '12_10-5s-F.csv', '12_11-5s-F.csv', '12_12-5s-F.csv', '12_13-5s-F.csv', '12_14-5s-F.csv', '12_15-5s-F.csv', '12_16-5s-F.csv', '12_17-5s-F.csv', '12_18-5s-F.csv', '12_19-5s-F.csv', '12_20-5s-F.csv', '12_21-5s-F.csv', '12_22-5s-F.csv', '12_23-5s-F.csv', '12_24-5s-F.csv', '12_25-5s-F.csv', '12_26-5s-F.csv', '12_27-5s-F.csv', '12_28-5s-F.csv', '12_29-5s-F.csv', '12_30-5s-F.csv', '12_31-5s-F.csv', '12_32-5s-F.csv', '12_33-5s-F.csv', '12_34-5s-F.csv', '12_35-5s-F.csv', '12_36-5s-F.csv', '12_37-5s-F.csv', '12_38-5s-F.csv', '12_39-5s-F.csv', '12_40-5s-F.csv', '12_41-5s-F.csv', '12_42-5s-F.csv', '12_43-5s-F.csv', '12_44-5s-F.csv', '12_45-5s-F.csv', '12_46-5s-F.csv', '12_47-5s-F.csv', '12_48-5s-F.csv', '12_49-5s-F.csv', '12_50-5s-F.csv', '12_51-5s-F.csv', '12_52-5s-F.csv', '12_53-5s-F.csv', '12_54-5s-F.csv', '12_55-5s-F.csv', '12_56-5s-F.csv', '12_57-5s-F.csv', '12_58-5s-F.csv', '12_59-5s-F.csv', '12_60-5s-F.csv', '12_61-5s-F.csv', '12_62-5s-F.csv', '12_63-5s-F.csv', '12_64-5s-F.csv', '12_65-5s-F.csv', '12_66-5s-F.csv', '12_67-5s-F.csv', '12_68-5s-F.csv', '12_69-5s-F.csv', '12_70-5s-F.csv', '12_71-5s-F.csv', '12_72-5s-F.csv', '12_73-5s-F.csv', '12_74-5s-F.csv', '12_75-5s-F.csv']
# 100001
# 100001
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100002
# 100001
# 100002
# 100002
# 100001
# 100001
# 100002
# 100002
# 100002
# 100002
# 100001
# 100001
# 100001
# 100002
# 100002
# 100002
# 100002
# 100001
# 100002
# 100002
# 100001
# 100001
# 100002
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100002
# 100002
# 100002
# 100002
# 100001
# 100001
# 100002
# 100002
# 100002
# 100002
# 100002
# 100002
# 100001
# 100002
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100002
# 100002
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100001

# %%
import csv
import pandas as pd
import numpy as np
import os,sys
import re

if __name__ == '__main__':
    for i in range(17, 21):
        
        
        filenames_in = 'C:/Users/1/force/force-3-F/'+ str(i) + '-5s-F'
        filenames_out = 'C:/Users/1/force/force-4-O/' + str(i) + '-5s-O'

        pathDir = os.listdir(filenames_in)
        print(pathDir)
        for allDir in pathDir:
            child = re.findall(r"(.+?).csv", allDir)
            if len(child) > 0:
                newfile = ''
                needdate = child
            domain1 = os.path.abspath(filenames_in)
            info = os.path.join(domain1, allDir)
            domain2 = os.path.abspath(filenames_out)
            outfo = os.path.join(domain2, allDir)
        
            n = len(open(info,"r").readlines())
            print(n)
        
            with open(info, 'r') as f:
                with open(outfo,'w') as f1:
                    next(f)
                    for line in f:
                        f1.write(line)
# Out:
# ['17_01-5s-F.csv', '17_02-5s-F.csv', '17_03-5s-F.csv', '17_04-5s-F.csv', '17_05-5s-F.csv', '17_06-5s-F.csv', '17_07-5s-F.csv', '17_08-5s-F.csv', '17_09-5s-F.csv', '17_10-5s-F.csv', '17_11-5s-F.csv', '17_12-5s-F.csv', '17_13-5s-F.csv', '17_14-5s-F.csv', '17_15-5s-F.csv', '17_16-5s-F.csv', '17_17-5s-F.csv', '17_18-5s-F.csv', '17_19-5s-F.csv', '17_20-5s-F.csv', '17_21-5s-F.csv', '17_22-5s-F.csv', '17_23-5s-F.csv']
# 100001
# 100001
# 100001
# 100002
# 100002
# 100002
# 100002
# 100001
# 100002
# 100001
# 100002
# 100001
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100002
# 100001
# ['18_01-5s-F.csv', '18_02-5s-F.csv', '18_03-5s-F.csv', '18_04-5s-F.csv', '18_05-5s-F.csv', '18_06-5s-F.csv', '18_07-5s-F.csv', '18_08-5s-F.csv', '18_09-5s-F.csv', '18_10-5s-F.csv', '18_11-5s-F.csv', '18_12-5s-F.csv', '18_13-5s-F.csv', '18_14-5s-F.csv']
# 100001
# 100002
# 100001
# 100002
# 100001
# 100002
# 100001
# 100001
# 100000
# 100001
# 100002
# 100002
# 100001
# 100001
# ['19_01-5s-F.csv', '19_02-5s-F.csv', '19_03-5s-F.csv', '19_04-5s-F.csv', '19_05-5s-F.csv', '19_06-5s-F.csv', '19_07-5s-F.csv', '19_08-5s-F.csv', '19_09-5s-F.csv', '19_10-5s-F.csv', '19_11-5s-F.csv', '19_12-5s-F.csv', '19_13-5s-F.csv', '19_14-5s-F.csv', '19_15-5s-F.csv', '19_16-5s-F.csv', '19_17-5s-F.csv', '19_18-5s-F.csv', '19_19-5s-F.csv']
# 100001
# 100001
# 100002
# 100001
# 100002
# 100001
# 100002
# 100002
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100001
# 100002
# 100001
# 100001
# 100001
# ['20_01-5s-F.csv', '20_02-5s-F.csv', '20_03-5s-F.csv', '20_04-5s-F.csv', '20_05-5s-F.csv', '20_06-5s-F.csv', '20_07-5s-F.csv', '20_08-5s-F.csv', '20_09-5s-F.csv', '20_10-5s-F.csv', '20_11-5s-F.csv']
# 100002
# 100002
# 100002
# 100001
# 100002
# 100001
# 100001
# 100002
# 100001
# 100002
# 100001
